# %% [markdown]
# ### **1. Set the variable test1 to the string 'This is a test of the emergency text system,' and save test1 to a file named test.txt.**
#
# You store the given sentence inside a variable named **test1**. Then you write that text into a file called **test.txt** so the sentence is saved permanently on your system.
#
# ---
#
# ### **2. Read the contents of the file test.txt into the variable test2. Is there a difference between test1 and test2?**
#
# You read the same text from the file and store it in a variable named **test2**.
# If the file was written properly, **test1 and test2 will be identical** because both contain the same sentence.
#
# ---
#
# ### **3. Create a CSV file called books.csv by using the given lines.**
#
# You make a new file named **books.csv** and add the header (title, author, year) followed by each book on a new line.
# A CSV is simply text separated by commas, so this creates a small table of book data.
#
# ---
#
# ### **4. Use the sqlite3 module to create a SQLite database called books.db, and a table called books with fields title (text), author (text), and year (integer).**
#
# You create a new database file named **books.db**.
# Inside it, you create a table called **books** with three columns: title, author, and year. This sets up a proper structure to store the book records.
#
# ---
#
# ### **5. Read books.csv and insert its data into the books table.**
#
# You open the CSV file, read each row, and insert those values into the **books** table in the database.
# This transfers the book list from a text file into the database structure.
#
# ---
#
# ### **6. Select and print the title column from the book table in alphabetical order.**
#
# You fetch only the **title** column from the table and sort the titles alphabetically before printing them.
# This shows the book names arranged from A to Z.
#
# ---
#
# ### **7. From the book table, select and print all columns in the order of publication.**
#
# You select **title, author, and year** for all books and sort them by the **year** column.
# This prints the books from the oldest publication year to the latest.
#
# ---
#
# ### **8. Use the sqlalchemy module to connect to the sqlite3 database books.db.**
#
# You use SQLAlchemy to create a connection to **books.db**.
# SQLAlchemy provides a higher-level way to interact with the database and run queries or use ORM features.
#
# ---
#
# ### **9. Install Redis and the redis Python library. Create a Redis hash called test with count (1) and name ('Fester Bestertester'). Print all fields.**
#
# After installing Redis, you create a **hash** named **test**.
# This hash contains two key–value pairs:
#
# * count = 1
# * name = "Fester Bestertester"
#   You then retrieve and print all the stored fields in that hash.
#
# ---
#
# ### **10. Increment the count field of test and print it.**
#
# You increase the value of the **count** field in the Redis hash by 1.
# After incrementing, you print the updated value, which becomes **2**.
#
# -
