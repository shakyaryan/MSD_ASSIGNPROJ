# %%
#       1. Write a Python Program to find sum of array?
array = [1,2,3,4,5]
sum = 0
for num in array:
    sum=sum+num

print("the sum of array elemnts :" , sum)
# Out:
# the sum of array elemnts : 15

# %%
# Write a Python Program to find largest element in an array?

array = [1,2,3,44,5]
largest = array[0]

for i in array:
    if i> largest:
        largest =i
    
print("The largest element in the array is:", largest)
# Out:
# The largest element in the array is: 44

# %%
# Write a Python Program for array rotation?
array = [1,2,3,4,5]
k = 3
rotated_array= array[k:]+array[:k]
print("Rotated array:", rotated_array)
# Out:
# Rotated array: [4, 5, 1, 2, 3]

# %%
# Write a Python Program to Split the array and add the first part to the end?
# Split the array and add the first part to the end

# Step 1: Input array
arr = [1, 2, 3, 4, 5, 6]

# Step 2: Input split position
n = 2

# Step 3: Handle if n > length
n = n % len(arr)

# Step 4: Split and rearrange
new_arr = arr[n:] + arr[:n]

# Step 5: Display the result
print("Original array:", arr)
print("Array after split and add:", new_arr)
# Out:
# Original array: [1, 2, 3, 4, 5, 6]
# Array after split and add: [3, 4, 5, 6, 1, 2]

# %%
# Write a Python Program to check if given array is Monotonic?
# Check if an array is monotonic

def is_monotonic(arr):
    return (all(arr[i] <= arr[i+1] for i in range(len(arr)-1)) or
            all(arr[i] >= arr[i+1] for i in range(len(arr)-1)))

# Example
arr = [1, 2, 2, 3]
print("Array is Monotonic:", is_monotonic(arr))
# Out:
# Array is Monotonic: True
