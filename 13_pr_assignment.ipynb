# %% [markdown]
# Question 1:
#
#
# Write a program that calculates and prints the value according to the given formula:
#
#
# Q = Square root of [(2 * C * D)/H]
#
# Following are the fixed values of C and H:
#
# C is 50. H is 30.

# %%
import math
D = [100,150,180]
C= 50
H= 30
Q= []

for d in D:
    q= math.sqrt((2*C*d)/H)
    Q.append(round(q))

print(Q)
# Out:
# [18, 22, 24]

# %% [markdown]
# Question 2:
#
# Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional array.
#
#  The element value in the i-th row and j-th column of the array should be i*j.
# Note: i=0,1.., X-1; j=0,1,¡Y-1.

# %%
X = 3 
Y = 5
result = []

for i in range(X):
    row = []
    for j in range(Y):
        row.append(i * j)   # correct: append()
    result.append(row)       # after completing the row

print(result)
# Out:
# [[0, 0, 0, 0, 0], [0, 1, 2, 3, 4], [0, 2, 4, 6, 8]]

# %% [markdown]
# Question 3:
#
#
# Write a program that accepts a comma separated sequence of words as input and prints the
# words in a comma-separated sequence after sorting them alphabetically.

# %%
word = 'without,hello,bag,world'

word_list = word.split(",")   # split into list
word_list.sort()              # sort alphabetically
result = ",".join(word_list)  # join back

print(result)
# Out:
# bag,hello,without,world

# %% [markdown]
# Question 4:
#
# Write a program that accepts a sequence of whitespace separated words as input and prints
# the words after removing all duplicate words and sorting them alphanumerically.

# %%
words = "hello world and practice makes perfect and hello world again"

# Step 1: split by whitespace
words_list = words.split()

# Step 2: remove duplicates using set
unique_words = set(words_list)

# Step 3: sort alphabetically
sorted_words = sorted(unique_words)

# Step 4: join back with space
result = " ".join(sorted_words)

print(result)
# Out:
# again and hello makes perfect practice world

# %%
"""  
Question 5:
Write a program that accepts a sentence and calculate the number of letters and digits.

"""
# Out:
# '  \nQuestion 5:\nWrite a program that accepts a sentence and calculate the number of letters and digits.\n\n'

# %%
sentence = "hello world! 123"
letters = 0
digits = 0

for ch in sentence:
    if ch.isalpha():
        letters += 1
    elif ch.isdigit():
        digits += 1

print("Letters:", letters)
print("Digits:", digits)
# Out:
# Letters: 10
# Digits: 3
