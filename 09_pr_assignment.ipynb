# %%
# Write a Python program to check if the given number is a Disarium Number?

n = int(input("Enter the number : ")) 
temp = n
x=n
# finding position
count =0

while temp>0:
      temp = temp//10
      count=count+1
sum=0
while x>0:
    rem = x%10 # individual digit
    sum = sum+rem**count
    x=x//10
    count = count-1
if sum==n:
     print(n , " is a Disarium number")
else:
     print(n, "is not a disarium number")
# Out:
# 135  is a Disarium number

# %%
# Write a Python program to print all disarium numbers between 1 to 100?

# function to check ifa number is disariom or not
def is_disarium(n):
    temp=n
    count=0
    # count digits
    while temp>0:
        temp=temp//10
        count+=1
    sum = 0
    x=n 

    # calculate sum of digits powered with thier positions
    while x>0:
        rem = x%10
        sum+=rem**count
        x=x//10
        count -=1
    return sum == n

# print disarium number from 1 to 100
print("Disarium numbers from 1 to 100:")
for i in range(1,101):
    if is_disarium(i):
        print(i)
# Out:
# Disarium numbers from 1 to 100:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 89

# %%
# Write a Python program to check if the given number is Happy Number


n = int(input("Enter the number : "))

def sum_of_squares(num):
    s = 0
    while num > 0:
        digit = num % 10
        s += digit * digit
        num = num // 10
    return s

num = n
seen = set()

while num != 1 and num not in seen:
    seen.add(num)
    num = sum_of_squares(num)

if num == 1:
    print(n, "is a Happy Number")
else:
    print(n, "is NOT a Happy Number")
# Out:
# 19 is a Happy Number

# %%
#   Write a Python program to print all happy numbers between 1 and 100?
def sum_of_squares(num):
    s = 0
    while num > 0:
        digit = num % 10
        s += digit * digit
        num = num // 10
    return s

def is_happy(n):
    num = n
    seen = set()          # to detect loop

    while num != 1 and num not in seen:
        seen.add(num)
        num = sum_of_squares(num)

    return num == 1       # True if happy

# print all happy numbers from 1 to 100
for i in range(1, 101):
    if is_happy(i):
        print(i)
# Out:
# 1
# 7
# 10
# 13
# 19
# 23
# 28
# 31
# 32
# 44
# 49
# 68
# 70
# 79
# 82
# 86
# 91
# 94
# 97
# 100

# %%
# Write a Python program to determine whether the given number is a Harshad Number?

n = int(input("Enter a number: "))

temp = n
digit_sum = 0

# Find sum of digits
while temp > 0:
    digit = temp % 10
    digit_sum += digit
    temp = temp // 10

# Check Harshad condition
if n % digit_sum == 0:
    print(n, "is a Harshad Number")
else:
    print(n, "is NOT a Harshad Number")
# Out:
# 12 is a Harshad Number

# %%
#Write a Python program to print all pronic numbers between 1 and 100?
print("Pronic numbers between 1 and 100:")

for i in range(1, 100):
    pronic = i * (i + 1)
    if pronic <= 100:
        print(pronic)
# Out:
# Pronic numbers between 1 and 100:
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90
