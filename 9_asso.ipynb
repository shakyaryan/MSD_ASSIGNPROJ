# %% [markdown]
# 1. To what does a relative path refer?
# 2. What does an absolute path start with your operating system?
# 3. What do the functions os.getcwd() and os.chdir() do?
# 4. What are the . and .. folders?
# 5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?
# 6. What are the three “mode” arguments that can be passed to the open() function?
# 7. What happens if an existing file is opened in write mode?
# 8. How do you tell the difference between read() and readlines()?
# 9. What data structure does a shelf value resemble?

# %% [markdown]
# 1. A relative path points to a location based on the current working directory.
#    It doesn’t start from the root folder.
#
# 2. An absolute path starts from the root directory.
#    In Windows, it begins with a drive letter like C:, in Linux/Mac with /.
#
# 3. os.getcwd() shows the current working directory.
#    os.chdir() changes the current working directory.
#
# 4. “.” means the current folder.
#    “..” means the parent folder.
#
# 5. In C:\bacon\eggs\spam.txt, dir name is C:\bacon\eggs.
#    Base name is spam.txt.
#
# 6. The three modes are “r” (read), “w” (write), and “a” (append).
#    They decide how the file will be opened.
#
# 7. Opening an existing file in write mode erases all its contents.
#    It then starts writing new data from the beginning.
#
# 8. read() gives the whole file as one string.
#    readlines() gives a list where each item is a line.
#
# 9. A shelf value works like a dictionary.
#    It stores key-value pairs.
