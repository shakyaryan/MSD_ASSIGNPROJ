# %% [markdown]
# 1.
#
# The result is: 1 2 8
# Reason: The function is called with a = 1 and b = 2. The third argument c is not given, so it uses its default value 8.
#
# ---
#
# 2.
#
# The result is: 1 2 3
# Reason: You give a = 1, b = 2, and c = 3 using keyword arguments. The function prints the values in the order a, b, c.
#
# ---
#
# 3.
#
# The result is: 1 (2, 3)
# Reason: The first value goes into a. All extra positional values (2 and 3) are collected into pargs as a tuple.
#
# ---
#
# 4.
#
# The result is: 1 {'c': 3, 'b': 2}
# Reason: The argument a = 1 goes into a. All other keyword arguments go into kargs as a dictionary containing b = 2 and c = 3.
#
# ---
#
# 5.
#
# The result is: 1 5 6 5
# Reason: The tuple (5, 6) expands into two positional arguments. So a = 1, b = 5, c = 6. The last value d was not provided so it stays at its default, which is 5.
#
# ---
#
# 6.
#
# The final values are:
# l = 1
# m = ['x']
# n = {'a': 'y'}
# Reason: Inside the function, a is changed to 2 but that does not affect l because integers do not change in place. The list m is changed because b[0] = 'x' modifies the actual list. The dictionary n is also changed because c['a'] = 'y' modifies the dictionary object.
#
# ---
