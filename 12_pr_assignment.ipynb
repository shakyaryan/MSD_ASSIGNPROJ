# %%
#Write a Python program to Extract Unique values dictionary values?

data = {
    "key": "value",
    "jatin": "gaya",
    "name": "Chirag",
    "age": 21,
    "course": "Data Science"
}

unique_values = set(data.values())
print(unique_values)
# Out:
# {'Data Science', 'gaya', 'value', 'Chirag', 21}

# %%
# 2. Write a Python program to find the sum of all items in a dictionary?

data = {"a": 10, "b": 20, "c": 30}

total = sum(data.values())
print(total)
# Out:
# 60

# %%
#   3. Write a Python program to Merging two Dictionaries?

dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged = dict1 | dict2
print(merged)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

dict1.update(dict2)
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#   4. Write a Python program to convert key-values list to flat dictionary?

 #Example-1
 #Analogy: Suppose you have a list of students and their 

students = ['Arun', 'Bob', 'Charlie']
grades = [85, 92, 78]
# Creating a dictionary using dictionary comprehension
grade_dict = {student: grade for student, grade in zip(students,grades)}
print(grade_dict)
# Out:
# {'Arun': 85, 'Bob': 92, 'Charlie': 78}

# %%
#   5. Write a Python program to insertion at the beginning in OrderedDict?

ord_dic = {"b": 20, "c": 30}
# insert at beginign
new_item={"a":1}
data = {**new_item , **data}
print(data)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
data = {"b": 2, "c": 3}

# new pair
key = "a"
value = 1

# recreate
new_dict = {key: value}
new_dict.update(data)

print(new_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#   Write a Python program to check order of character in string using OrderedDict()?

from collections import OrderedDict

def check_order(string, pattern):
    ordered = OrderedDict.fromkeys(string)

    index = 0  # pattern index

    for char in ordered:
        if index < len(pattern) and char == pattern[index]:
            index += 1
    
    return index == len(pattern)


string = "engineers rock"
pattern = "er"

print(check_order(string, pattern))
# Out:
# True

# %%
#   7. Write a Python program to sort Python Dictionaries by Key or Value?

data = {"b": 3, "a": 1, "d": 4, "c": 2}

keys_sorted = sorted(list(data))   # list(data) is list of keys; sorted(...) sorts keys
print(keys_sorted)                 # ['a', 'b', 'c', 'd']
# Out:
# ['a', 'b', 'c', 'd']
